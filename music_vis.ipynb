# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable

import sys
import time
import numpy as np
import random
import matplotlib.pyplot as plt

from utils import *
log = logger(True) ; log("We're logging :)") #Log will print whatever it's given if this first arg is true

# Auto-reloading of modules in iPython
# %load_ext autoreload
# %autoreload 2

# CONSTS
SAVE_EVERY = 20
SEQ_SIZE = 25
RANDOM_SEED = 11
VALIDATION_SIZE = 0.15
LR = 1e-3
N_EPOCHS = 100
NUM_LAYERS, HIDDEN_SIZE = 1, 100
DROPOUT_P = 0
model_type = 'lstm'
use_cuda = torch.cuda.is_available() ; log("use_cuda is: %s" % use_cuda)
torch.manual_seed(RANDOM_SEED)
INPUT = 'data/music.txt'  # Music
RESUME = False
CHECKPOINT = 'ckpt_mdl_{}_ep_{}_hsize_{}_dout_{}_RMSprop'.format(model_type, N_EPOCHS, HIDDEN_SIZE, DROPOUT_P)
# Out:
# We're logging :)
# use_cuda is: False

# %%
# READ IN DATA FILE
f = open(INPUT,"r")
data, buffer = [], ''
store = False
for line in f:
    if line == '<start>\n':
        buffer += line
    elif line == '<end>\n':
        buffer += line
        data += [buffer]
        buffer = ''
    else:
        buffer += line
f.close()

# We only want songs which are at least as big as our batch size +1
data = [ song for song in data if len(song) > SEQ_SIZE + 10 ]
log(data[0])
log('=====> Data loaded')
# Out:
# <start>
# X:1
# T: La Montfarine
# Z:Transcrit et/ou corrig? par Michel BELLON - 2005-07-24
# Z:Pour toute observation mailto:galouvielle@free.fr
# M: 4/4
# L: 1/8
# Q:1/4=186
# FGF B=AG G=AG F2F FGF {F}F2E EFE|
# {E}E2D FGF B=AG G=AG {F}F2F FED C2G D2E|F3 {F}F/2 ED E3/2D/2|
# EC FE E2 DC|DC C2 GD2E|F3F/2F/2 DE FD|EC B,C D2 B,G|
# cB =A2 FG2E|F3F GF B=A|GG =AG F2 FF|GF F/2F3/2 EE FE|
# E/2E3/2 DF GF B=A|GG =AG F/2F3/2 FF|ED C2 GD2E|F3F/2F/2 ED E3/2D/2|
# EC FE E2 DC|DC C2 GD2E|F3F/2F/2 DE FD|EC B,C D2 B,G|
# cB =A2 FF G=A|B3
# G2_A G/2G3/2-|GF/2F/2 ED F2 EB,|CD EF GB AG|
# A3A GA F2|F/2F/2F EF D3/2B,/2 B,B,|CD EF GA GF|G3B/2B/2 AB G2|
# GG/2G/2 FG E2 EB/2B/2|AG BA GG AB|c3c/2c3/2d f2|ed eG c2 BB|
# AB dc BG AD|E3F GF BA|GG AG F2 FF|GF F/2F3/2 EE FE|
# E/2E3/2 DF GF BA|GG AG F/2F3/2 FF|ED C2 GD2E|F2- F/2
# <end>
#
# =====> Data loaded

# %%
char_idx = ''.join(set(list(open(INPUT,'r').read())))
char_list = list(char_idx)

# NOW SPLIT INTO TRAIN/VALIDATION SETS
num_train = len(data)
indices = list(range(num_train))
split_idx = int(np.floor(VALIDATION_SIZE * num_train))

# Shuffle data and split
np.random.seed(RANDOM_SEED)
np.random.shuffle(indices)
train_idxs, valid_idxs = indices[split_idx:], indices[:split_idx]

train_len, valid_len = len(train_idxs), len(valid_idxs)
log('Number of unique characters: %s' % len(char_idx))
log('Original data length: %s' % len(data))
log('Training data length: %s'% train_len)
log('Validation data length: %s' % valid_len)
assert(train_len + valid_len == len(data)), 'Train_len + valid_len should == len(data)'
# Out:
# Number of unique characters: 93
# Original data length: 1120
# Training data length: 952
# Validation data length: 168

# %%
# Some utils
def tic(): return time.time()

def toc(tic, msg=None):
    s = time.time() - tic
    m = int(s / 60)
    if msg:
        return '{}m {}s {}'.format(m, int(s - (m * 60)), msg)
    return '{}m {}s'.format(m, int(s - (m * 60)))

# Gives us a random slice of size SEQ_SIZE + 1 so we can get a train/target.
def rand_slice(data, slice_len=SEQ_SIZE):
    d_len = len(data)
    s_idx = random.randint(0, d_len - slice_len)
    e_idx = s_idx + slice_len + 1
    return data[s_idx:e_idx]

test_slice = rand_slice(data[0])
log(test_slice)

def seq_to_tensor(seq):
    '''
    create tensor from char seq
    '''
    out = torch.zeros(len(seq)).long()
    for i, c in enumerate(seq):
        out[i] = char_idx.index(c)
    return out

t = seq_to_tensor(test_slice)
log('T is a: ', type(t), ' of size ', len(t))

def train_slice(data, slice_len=50):
    '''
    creates a random training set
    '''
    slice_i = rand_slice(data, slice_len=slice_len)
    seq = seq_to_tensor(slice_i[:-1])
    target = seq_to_tensor(slice_i[1:])
    return Variable(seq), Variable(target)

def train_batch(data, b_size=100, slice_len=50):
    batch_seq = torch.zeros(b_size, slice_len).long()
    batch_target = torch.zeros(b_size, slice_len).long()
    for idx in range(b_size):
        seq, target = train_slice(data, slice_len=slice_len)
        batch_seq[idx] = seq.data
        batch_target[idx] = target.data
    return Variable(batch_seq), Variable(batch_target)

# Given a song, return a sequence/target as a variable
def song_to_seq_target(song):
    a_slice = rand_slice(song)
    seq = seq_to_tensor(a_slice[:-1])
    target = seq_to_tensor(a_slice[1:])
    assert(len(seq) == len(target)), 'SEQ AND TARGET MISMATCH'
    return Variable(seq), Variable(target)

s, t = song_to_seq_target(data[0])
log(s.size())
assert(t.data[0] == s.data[1])
# Out:
# 005-07-24
# Z:Pour toute obs
# T is a:  <class 'torch.LongTensor'>  of size  26
# torch.Size([25])

# %%
class MusicRNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, model='gru', num_layers=1):
        super(MusicRNN, self).__init__()
        self.model = model
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        
        self.embeddings = nn.Embedding(input_size, hidden_size)
        if self.model == 'lstm':
            self.rnn = nn.LSTM(hidden_size, hidden_size, num_layers)
        elif self.model == 'gru':
            self.rnn = nn.GRU(hidden_size, hidden_size, num_layers)
        else:
            raise NotImplementedError
        self.out = nn.Linear(self.hidden_size, self.output_size)
        self.drop = nn.Dropout(p=DROPOUT_P)
        
    def init_hidden(self):
        if self.model == 'lstm':
            self.hidden = (Variable(torch.zeros(self.num_layers, 1, self.hidden_size)),
                           Variable(torch.zeros(self.num_layers, 1, self.hidden_size)))
        elif self.model == 'gru':
            self.hidden = Variable(torch.zeros(self.num_layers, 1, self.hidden_size))
        
    def forward(self, seq):
        embeds = self.embeddings(seq.view(1, -1))
        rnn_out, self.hidden = self.rnn(embeds.view(1,1,-1), self.hidden)
        rnn_out = self.drop(rnn_out)
        output = self.out(rnn_out.view(1,-1))
        return output

# %%
def some_pass(seq, target, fit=True):
    model.init_hidden() # Zero out the hidden layer
    model.zero_grad()   # Zero out the gradient
    some_loss = 0
    
    for i, c in enumerate(seq):
        output = model(c)
        some_loss += loss_function(output, target[i])
        
    if fit:
        some_loss.backward()
        optimizer.step()
    
    return some_loss.data[0] / len(seq)

# %%
# Model
if RESUME:
    # Load checkpoint.
    print('==> Resuming from checkpoint..')
    assert os.path.isdir('checkpoint'), 'Error: no checkpoint directory found!'
    
    checkpoint = torch.load('./checkpoint/' + CHECKPOINT + '.tEP_NUM_SVAED')
    model = checkpoint['model']
    loss = checkpoint['loss']
    v_loss = checkpoint['v_loss']
    losses = checkpoint['losses']
    v_losses = checkpoint['v_losses']
    start_epoch = checkpoint['epoch']
    
else:
    print('==> Building model..')
    in_size, out_size = len(char_idx), len(char_idx)
    model = MusicRNN(in_size, HIDDEN_SIZE, out_size, model_type, NUM_LAYERS)
    loss, v_loss = 0, 0
    losses, v_losses = [], []
    start_epoch = 0

if use_cuda:
    net.cuda()
    net = torch.nn.DataParallel(net, device_ids=range(torch.cuda.device_count()))
    cudnn.benchmark = True

optimizer = torch.optim.Adam(model.parameters(), lr=LR)
# optimizer = torch.optim.SGD(model.parameters(), lr=LR, momentum=0.9)
# optimizer = torch.optim.Adagrad(model.parameters())
# optimizer = torch.optim.RMSprop(model.parameters())

loss_function = nn.CrossEntropyLoss()
# Out:
# ==> Building model..

# %%
# Train
time_since = tic()
for epoch in range(start_epoch, N_EPOCHS):
    # Training
    for i, song_idx in enumerate(train_idxs):
        this_loss = some_pass(*song_to_seq_target(data[song_idx]))
        loss += this_loss
        
        msg = '\rTraining Epoch: {}, {:.2f}% iter: {} Time: {} Loss: {:.4}'.format(
             epoch, (i+1)/len(train_idxs)*100, i, toc(time_since), this_loss)
        sys.stdout.write(msg)
        sys.stdout.flush()
    print()
    losses.append(loss / len(train_idxs))
        
    # Validation
    for i, song_idx in enumerate(valid_idxs):
        this_loss = some_pass(*song_to_seq_target(data[song_idx]), fit=False)
        v_loss += this_loss
        
        msg = '\rValidation Epoch: {}, {:.2f}% iter: {} Time: {} Loss: {:.4}'.format(
             epoch, (i+1)/len(valid_idxs)*100, i, toc(time_since), this_loss)
        sys.stdout.write(msg)
        sys.stdout.flush()
    print()
    v_losses.append(v_loss / len(valid_idxs))
    
    # Save checkpoint.
    if epoch % SAVE_EVERY == 0 and start_epoch != epoch or epoch == N_EPOCHS - 1:
        print('=======>Saving..')
        state = {
            'model': model.module if use_cuda else model,
            'loss': losses[-1],
            'v_loss': v_losses[-1],
            'losses': losses,
            'v_losses': v_losses,
            'epoch': epoch,
        }
        if not os.path.isdir('checkpoint'):
            os.mkdir('checkpoint')
#         torch.save(state, './checkpoint/ckpt.t%s' % epoch)
        torch.save(state, './checkpoint/' + CHECKPOINT + '.t%s' % epoch)
    
    # Reset loss
    loss, v_loss = 0, 0
# Out:
# Training Epoch: 0, 100.00% iter: 951 Time: 0m 27s Loss: 1.847
# Validation Epoch: 0, 100.00% iter: 167 Time: 0m 30s Loss: 3.456
# Training Epoch: 1, 100.00% iter: 951 Time: 0m 54s Loss: 2.358
# Validation Epoch: 1, 100.00% iter: 167 Time: 0m 56s Loss: 2.752
# Training Epoch: 2, 100.00% iter: 951 Time: 1m 19s Loss: 1.872
# Validation Epoch: 2, 100.00% iter: 167 Time: 1m 22s Loss: 2.379
# Training Epoch: 3, 100.00% iter: 951 Time: 1m 47s Loss: 1.724
# Validation Epoch: 3, 100.00% iter: 167 Time: 1m 49s Loss: 1.253
# Training Epoch: 4, 100.00% iter: 951 Time: 2m 14s Loss: 1.701
# Validation Epoch: 4, 100.00% iter: 167 Time: 2m 17s Loss: 2.377
# Training Epoch: 5, 100.00% iter: 951 Time: 2m 40s Loss: 1.594
# Validation Epoch: 5, 100.00% iter: 167 Time: 2m 42s Loss: 2.022
# Training Epoch: 6, 100.00% iter: 951 Time: 3m 9s Loss: 1.5265
# Validation Epoch: 6, 100.00% iter: 167 Time: 3m 11s Loss: 2.095
# Training Epoch: 7, 100.00% iter: 951 Time: 3m 35s Loss: 1.503
# Validation Epoch: 7, 100.00% iter: 167 Time: 3m 37s Loss: 2.033
# Training Epoch: 8, 100.00% iter: 951 Time: 4m 1s Loss: 0.7032
# Validation Epoch: 8, 100.00% iter: 167 Time: 4m 3s Loss: 2.654
# Training Epoch: 9, 100.00% iter: 951 Time: 4m 26s Loss: 1.306
# Validation Epoch: 9, 100.00% iter: 167 Time: 4m 28s Loss: 2.331
# Training Epoch: 10, 100.00% iter: 951 Time: 4m 51s Loss: 1.468
# Validation Epoch: 10, 100.00% iter: 167 Time: 4m 53s Loss: 2.415
# Training Epoch: 11, 100.00% iter: 951 Time: 5m 16s Loss: 0.589
# Validation Epoch: 11, 100.00% iter: 167 Time: 5m 18s Loss: 2.169
# Training Epoch: 12, 100.00% iter: 951 Time: 5m 41s Loss: 1.479
# Validation Epoch: 12, 100.00% iter: 167 Time: 5m 43s Loss: 2.426
# Training Epoch: 13, 100.00% iter: 951 Time: 6m 5s Loss: 1.4732
# Validation Epoch: 13, 100.00% iter: 167 Time: 6m 7s Loss: 0.3464
# Training Epoch: 14, 100.00% iter: 951 Time: 6m 30s Loss: 2.472
# Validation Epoch: 14, 100.00% iter: 167 Time: 6m 33s Loss: 2.491
# Training Epoch: 15, 100.00% iter: 951 Time: 6m 56s Loss: 2.225
# Validation Epoch: 15, 100.00% iter: 167 Time: 6m 58s Loss: 2.571
# Training Epoch: 16, 100.00% iter: 951 Time: 7m 21s Loss: 1.274
# Validation Epoch: 16, 100.00% iter: 167 Time: 7m 23s Loss: 2.822
# Training Epoch: 17, 100.00% iter: 951 Time: 7m 46s Loss: 1.209
# Validation Epoch: 17, 100.00% iter: 167 Time: 7m 48s Loss: 1.647
# Training Epoch: 18, 100.00% iter: 951 Time: 8m 12s Loss: 1.481
# Validation Epoch: 18, 100.00% iter: 167 Time: 8m 15s Loss: 2.375
# Training Epoch: 19, 100.00% iter: 951 Time: 8m 45s Loss: 1.369
# Validation Epoch: 19, 100.00% iter: 167 Time: 8m 47s Loss: 2.201
# Training Epoch: 20, 100.00% iter: 951 Time: 9m 12s Loss: 1.461
# Validation Epoch: 20, 100.00% iter: 167 Time: 9m 15s Loss: 1.704
# =======>Saving..
# Training Epoch: 21, 0.63% iter: 5 Time: 9m 16s Loss: 1.987
# /Users/vchiley/anaconda3/lib/python3.6/site-packages/torch/serialization.py:158: UserWarning: Couldn't retrieve source code for container of type MusicRNN. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Training Epoch: 21, 100.00% iter: 951 Time: 9m 40s Loss: 1.439
# Validation Epoch: 21, 100.00% iter: 167 Time: 9m 42s Loss: 1.939
# Training Epoch: 22, 100.00% iter: 951 Time: 10m 4s Loss: 1.279
# Validation Epoch: 22, 100.00% iter: 167 Time: 10m 7s Loss: 1.988
# Training Epoch: 23, 100.00% iter: 951 Time: 10m 32s Loss: 1.214
# Validation Epoch: 23, 100.00% iter: 167 Time: 10m 34s Loss: 2.289
# Training Epoch: 24, 100.00% iter: 951 Time: 11m 3s Loss: 0.9185
# Validation Epoch: 24, 100.00% iter: 167 Time: 11m 5s Loss: 2.097
# Training Epoch: 25, 100.00% iter: 951 Time: 11m 28s Loss: 1.312
# Validation Epoch: 25, 100.00% iter: 167 Time: 11m 30s Loss: 1.808
# Training Epoch: 26, 100.00% iter: 951 Time: 11m 53s Loss: 1.604
# Validation Epoch: 26, 100.00% iter: 167 Time: 11m 55s Loss: 2.994
# Training Epoch: 27, 100.00% iter: 951 Time: 12m 18s Loss: 1.232
# Validation Epoch: 27, 100.00% iter: 167 Time: 12m 20s Loss: 2.809
# Training Epoch: 28, 100.00% iter: 951 Time: 12m 44s Loss: 1.385
# Validation Epoch: 28, 100.00% iter: 167 Time: 12m 46s Loss: 3.189
# Training Epoch: 29, 100.00% iter: 951 Time: 13m 9s Loss: 1.3432
# Validation Epoch: 29, 100.00% iter: 167 Time: 13m 11s Loss: 2.817
# Training Epoch: 30, 100.00% iter: 951 Time: 13m 33s Loss: 1.313
# Validation Epoch: 30, 100.00% iter: 167 Time: 13m 35s Loss: 2.399
# Training Epoch: 31, 100.00% iter: 951 Time: 14m 0s Loss: 1.4276
# Validation Epoch: 31, 100.00% iter: 167 Time: 14m 3s Loss: 2.617
# Training Epoch: 32, 100.00% iter: 951 Time: 14m 31s Loss: 1.214
# Validation Epoch: 32, 100.00% iter: 167 Time: 14m 33s Loss: 1.983
# Training Epoch: 33, 100.00% iter: 951 Time: 15m 1s Loss: 1.9358
# Validation Epoch: 33, 100.00% iter: 167 Time: 15m 3s Loss: 1.832
# Training Epoch: 34, 100.00% iter: 951 Time: 15m 26s Loss: 1.493
# Validation Epoch: 34, 100.00% iter: 167 Time: 15m 28s Loss: 2.398
# Training Epoch: 35, 100.00% iter: 951 Time: 15m 55s Loss: 1.388
# Validation Epoch: 35, 100.00% iter: 167 Time: 15m 57s Loss: 2.499
# Training Epoch: 36, 100.00% iter: 951 Time: 16m 19s Loss: 1.287
# Validation Epoch: 36, 100.00% iter: 167 Time: 16m 21s Loss: 1.693
# Training Epoch: 37, 100.00% iter: 951 Time: 16m 43s Loss: 2.228
# Validation Epoch: 37, 100.00% iter: 167 Time: 16m 45s Loss: 1.977
# Training Epoch: 38, 100.00% iter: 951 Time: 17m 11s Loss: 1.475
# Validation Epoch: 38, 100.00% iter: 167 Time: 17m 13s Loss: 1.633
# Training Epoch: 39, 100.00% iter: 951 Time: 17m 38s Loss: 2.139
# Validation Epoch: 39, 100.00% iter: 167 Time: 17m 40s Loss: 2.192
# Training Epoch: 40, 100.00% iter: 951 Time: 18m 6s Loss: 1.1744
# Validation Epoch: 40, 100.00% iter: 167 Time: 18m 8s Loss: 2.255
# =======>Saving..
# Training Epoch: 41, 100.00% iter: 951 Time: 18m 33s Loss: 1.604
# Validation Epoch: 41, 100.00% iter: 167 Time: 18m 35s Loss: 1.701
# Training Epoch: 42, 100.00% iter: 951 Time: 19m 0s Loss: 1.46887
# Validation Epoch: 42, 100.00% iter: 167 Time: 19m 2s Loss: 1.773
# Training Epoch: 43, 100.00% iter: 951 Time: 19m 26s Loss: 1.534
# Validation Epoch: 43, 100.00% iter: 167 Time: 19m 29s Loss: 2.109
# Training Epoch: 44, 100.00% iter: 951 Time: 19m 53s Loss: 1.259
# Validation Epoch: 44, 100.00% iter: 167 Time: 19m 55s Loss: 2.832
# Training Epoch: 45, 100.00% iter: 951 Time: 20m 19s Loss: 1.559
# Validation Epoch: 45, 100.00% iter: 167 Time: 20m 21s Loss: 1.208
# Training Epoch: 46, 100.00% iter: 951 Time: 20m 46s Loss: 1.375
# Validation Epoch: 46, 100.00% iter: 167 Time: 20m 48s Loss: 2.269
# Training Epoch: 47, 100.00% iter: 951 Time: 21m 12s Loss: 0.8387
# Validation Epoch: 47, 100.00% iter: 167 Time: 21m 14s Loss: 2.291
# Training Epoch: 48, 100.00% iter: 951 Time: 21m 43s Loss: 1.037
# Validation Epoch: 48, 100.00% iter: 167 Time: 21m 45s Loss: 1.203
# Training Epoch: 49, 100.00% iter: 951 Time: 22m 11s Loss: 1.217
# Validation Epoch: 49, 100.00% iter: 167 Time: 22m 13s Loss: 0.3676
# Training Epoch: 50, 100.00% iter: 951 Time: 22m 35s Loss: 1.626
# Validation Epoch: 50, 100.00% iter: 167 Time: 22m 37s Loss: 3.016
# Training Epoch: 51, 100.00% iter: 951 Time: 23m 3s Loss: 1.4758
# Validation Epoch: 51, 100.00% iter: 167 Time: 23m 6s Loss: 1.834
# Training Epoch: 52, 100.00% iter: 951 Time: 23m 36s Loss: 1.577
# Validation Epoch: 52, 100.00% iter: 167 Time: 23m 38s Loss: 2.562
# Training Epoch: 53, 100.00% iter: 951 Time: 24m 0s Loss: 1.3843
# Validation Epoch: 53, 100.00% iter: 167 Time: 24m 2s Loss: 1.467
# Training Epoch: 54, 100.00% iter: 951 Time: 24m 31s Loss: 1.694
# Validation Epoch: 54, 100.00% iter: 167 Time: 24m 34s Loss: 2.036
# Training Epoch: 55, 100.00% iter: 951 Time: 25m 0s Loss: 1.3155
# Validation Epoch: 55, 100.00% iter: 167 Time: 25m 2s Loss: 2.116
# Training Epoch: 56, 100.00% iter: 951 Time: 25m 28s Loss: 1.376
# Validation Epoch: 56, 100.00% iter: 167 Time: 25m 31s Loss: 1.873
# Training Epoch: 57, 100.00% iter: 951 Time: 25m 56s Loss: 1.277
# Validation Epoch: 57, 100.00% iter: 167 Time: 25m 58s Loss: 1.937
# Training Epoch: 58, 100.00% iter: 951 Time: 26m 24s Loss: 1.354
# Validation Epoch: 58, 100.00% iter: 167 Time: 26m 27s Loss: 2.249
# Training Epoch: 59, 100.00% iter: 951 Time: 26m 52s Loss: 1.157
# Validation Epoch: 59, 100.00% iter: 167 Time: 26m 53s Loss: 2.344
# Training Epoch: 60, 100.00% iter: 951 Time: 27m 17s Loss: 1.058
# Validation Epoch: 60, 100.00% iter: 167 Time: 27m 19s Loss: 2.423
# =======>Saving..
# Training Epoch: 61, 100.00% iter: 951 Time: 27m 44s Loss: 1.327
# Validation Epoch: 61, 100.00% iter: 167 Time: 27m 46s Loss: 2.075
# Training Epoch: 62, 100.00% iter: 951 Time: 28m 10s Loss: 1.673
# Validation Epoch: 62, 100.00% iter: 167 Time: 28m 12s Loss: 1.938
# Training Epoch: 63, 100.00% iter: 951 Time: 28m 36s Loss: 1.163
# Validation Epoch: 63, 100.00% iter: 167 Time: 28m 38s Loss: 2.313
# Training Epoch: 64, 100.00% iter: 951 Time: 29m 2s Loss: 1.5445
# Validation Epoch: 64, 100.00% iter: 167 Time: 29m 4s Loss: 1.796
# Training Epoch: 65, 100.00% iter: 951 Time: 29m 28s Loss: 1.435
# Validation Epoch: 65, 100.00% iter: 167 Time: 29m 30s Loss: 2.379
# Training Epoch: 66, 100.00% iter: 951 Time: 29m 54s Loss: 1.551
# Validation Epoch: 66, 100.00% iter: 167 Time: 29m 56s Loss: 3.145
# Training Epoch: 67, 100.00% iter: 951 Time: 30m 19s Loss: 1.085
# Validation Epoch: 67, 100.00% iter: 167 Time: 30m 21s Loss: 1.894
# Training Epoch: 68, 100.00% iter: 951 Time: 30m 43s Loss: 1.165
# Validation Epoch: 68, 100.00% iter: 167 Time: 30m 45s Loss: 2.107
# Training Epoch: 69, 100.00% iter: 951 Time: 31m 6s Loss: 1.1445
# Validation Epoch: 69, 100.00% iter: 167 Time: 31m 8s Loss: 2.115
# Training Epoch: 70, 100.00% iter: 951 Time: 31m 30s Loss: 1.204
# Validation Epoch: 70, 100.00% iter: 167 Time: 31m 32s Loss: 0.6712
# Training Epoch: 71, 100.00% iter: 951 Time: 31m 54s Loss: 1.325
# Validation Epoch: 71, 100.00% iter: 167 Time: 31m 56s Loss: 2.952
# Training Epoch: 72, 100.00% iter: 951 Time: 32m 28s Loss: 1.456
# Validation Epoch: 72, 100.00% iter: 167 Time: 32m 31s Loss: 2.569
# Training Epoch: 73, 100.00% iter: 951 Time: 32m 54s Loss: 1.252
# Validation Epoch: 73, 100.00% iter: 167 Time: 32m 56s Loss: 1.225
# Training Epoch: 74, 100.00% iter: 951 Time: 33m 19s Loss: 1.323
# Validation Epoch: 74, 100.00% iter: 167 Time: 33m 21s Loss: 2.132
# Training Epoch: 75, 100.00% iter: 951 Time: 33m 43s Loss: 1.496
# Validation Epoch: 75, 100.00% iter: 167 Time: 33m 45s Loss: 2.105
# Training Epoch: 76, 100.00% iter: 951 Time: 34m 8s Loss: 1.5091
# Validation Epoch: 76, 100.00% iter: 167 Time: 34m 10s Loss: 3.065
# Training Epoch: 77, 100.00% iter: 951 Time: 34m 34s Loss: 1.607
# Validation Epoch: 77, 100.00% iter: 167 Time: 34m 37s Loss: 2.963
# Training Epoch: 78, 100.00% iter: 951 Time: 35m 8s Loss: 1.2774
# Validation Epoch: 78, 100.00% iter: 167 Time: 35m 11s Loss: 2.346
# Training Epoch: 79, 100.00% iter: 951 Time: 35m 41s Loss: 1.164
# Validation Epoch: 79, 100.00% iter: 167 Time: 35m 44s Loss: 1.886
# Training Epoch: 80, 100.00% iter: 951 Time: 36m 14s Loss: 1.541
# Validation Epoch: 80, 100.00% iter: 167 Time: 36m 17s Loss: 2.172
# =======>Saving..
# Training Epoch: 81, 100.00% iter: 951 Time: 36m 46s Loss: 1.269
# Validation Epoch: 81, 100.00% iter: 167 Time: 36m 50s Loss: 1.627
# Training Epoch: 82, 100.00% iter: 951 Time: 37m 16s Loss: 1.208
# Validation Epoch: 82, 100.00% iter: 167 Time: 37m 18s Loss: 1.977
# Training Epoch: 83, 100.00% iter: 951 Time: 37m 41s Loss: 1.472
# Validation Epoch: 83, 100.00% iter: 167 Time: 37m 43s Loss: 2.637
# Training Epoch: 84, 100.00% iter: 951 Time: 38m 11s Loss: 1.403
# Validation Epoch: 84, 100.00% iter: 167 Time: 38m 15s Loss: 1.186
# Training Epoch: 85, 100.00% iter: 951 Time: 38m 50s Loss: 1.277
# Validation Epoch: 85, 100.00% iter: 167 Time: 38m 53s Loss: 0.5785
# Training Epoch: 86, 100.00% iter: 951 Time: 39m 24s Loss: 1.285
# Validation Epoch: 86, 100.00% iter: 167 Time: 39m 28s Loss: 1.494
# Training Epoch: 87, 100.00% iter: 951 Time: 40m 0s Loss: 1.4266
# Validation Epoch: 87, 100.00% iter: 167 Time: 40m 3s Loss: 2.548
# Training Epoch: 88, 100.00% iter: 951 Time: 40m 34s Loss: 1.461
# Validation Epoch: 88, 100.00% iter: 167 Time: 40m 37s Loss: 2.398
# Training Epoch: 89, 100.00% iter: 951 Time: 41m 7s Loss: 1.2532
# Validation Epoch: 89, 100.00% iter: 167 Time: 41m 10s Loss: 2.252
# Training Epoch: 90, 100.00% iter: 951 Time: 41m 41s Loss: 0.9291
# Validation Epoch: 90, 100.00% iter: 167 Time: 41m 44s Loss: 1.617
# Training Epoch: 91, 100.00% iter: 951 Time: 42m 12s Loss: 1.136
# Validation Epoch: 91, 100.00% iter: 167 Time: 42m 14s Loss: 2.267
# Training Epoch: 92, 100.00% iter: 951 Time: 42m 37s Loss: 1.231
# Validation Epoch: 92, 100.00% iter: 167 Time: 42m 39s Loss: 1.838
# Training Epoch: 93, 100.00% iter: 951 Time: 43m 2s Loss: 1.05193
# Validation Epoch: 93, 100.00% iter: 167 Time: 43m 4s Loss: 0.2702
# Training Epoch: 94, 100.00% iter: 951 Time: 43m 26s Loss: 1.3995
# Validation Epoch: 94, 100.00% iter: 167 Time: 43m 28s Loss: 0.1952
# Training Epoch: 95, 100.00% iter: 951 Time: 43m 54s Loss: 1.336
# Validation Epoch: 95, 100.00% iter: 167 Time: 43m 56s Loss: 1.794
# Training Epoch: 96, 100.00% iter: 951 Time: 44m 21s Loss: 1.295
# Validation Epoch: 96, 100.00% iter: 167 Time: 44m 23s Loss: 3.138
# Training Epoch: 97, 100.00% iter: 951 Time: 44m 47s Loss: 1.0052
# Validation Epoch: 97, 100.00% iter: 167 Time: 44m 49s Loss: 1.712
# Training Epoch: 98, 100.00% iter: 951 Time: 45m 12s Loss: 1.521
# Validation Epoch: 98, 100.00% iter: 167 Time: 45m 14s Loss: 2.883
# Training Epoch: 99, 100.00% iter: 951 Time: 45m 37s Loss: 1.052
# Validation Epoch: 99, 100.00% iter: 167 Time: 45m 39s Loss: 2.325
# =======>Saving..

# %%
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=12)     # fontsize of the axes title
plt.rc('axes', labelsize=0)      # fontsize of the x and y labels
plt.rc('xtick', labelsize=12)    # fontsize of the tick labels
plt.rc('ytick', labelsize=12)    # fontsize of the tick labels
plt.rc('legend', fontsize=12)    # legend fontsize
plt.rc('figure', titlesize=12)   # fontsize of the figure title
plt.plot(losses, label='Training Loss')
plt.plot(v_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss per Epoch')
plt.legend()
plt.show()

# %%
def write_song(prime_str='<start>', max_len=1000, temp=0.8):
    model.init_hidden()
    
    # "build up" hidden state using the beginging of a song '<start>'
    creation = '<start>'
    prime = Variable(seq_to_tensor(creation))
    for i in range(len(prime)-1):
        _ = model(prime[i])

    # Generate rest of sequence
    for j in range(max_len):
        out = model(Variable(seq_to_tensor(creation[-1]))).data.view(-1)
        
        out = np.array(np.exp(out/temp))
        dist = out / np.sum(out)

        # Add predicted character to string and use as next input        
        creation += char_idx[np.random.choice(len(dist), p=dist)]
        if creation[-5:] == '<end>':
            break

    return creation

# %%
log(write_song(max_len=1000, temp=0.8))
# Out:
# <start>
# X:2
# T:And Coine Glland by O'Carolan (1670-1738)
# Z:Transcrit et/ou corrig? pard
# C:Trad.
# M:2/4
# L:1/8
# Q:1/4=120
# K:Bbmajor
# "G"d3/2)/|"C"c2 c2|"Em"c2 e/2e/2d/2|"B\b"dB "Gm"F/F/A/c/ | dd/ cB/A/|"D"AB/A/ BAG|"G"c2dc ded2|"D"A2A B2B|"G"BAB "G"d3|"c2 e>d|"F"dBAF|"F"A2B "C|B2 "G7"dB"A2G F/G/A/B/|"F"fd ed|"C"e2e ed2|
# de/f/ e/d/B/A/|GF G/A/B/|d/e/f/e/ de/f/|eg g2|g/f/e/f/ | e/^c/d/e/ fe|dB AG:|
# [2 B2 BA B>c|
# B2 Bc|
# de dc|Bd cA|1 G2 GA:|
# Z:Transcrit et/ou corrig? par Michel BELLON - 2006-11-25
# Z:Pour toute observation mailto:galouvielle@free.fr
# M:2/4
# L:1/4
# Q:1/4=170
# K:C
# FAAF|GFED DDB,CD, :|2 ADD D3 D3 |
# d2B BAG | {F}FE3F | D2F | FFF ~A2B|
# ABc d2B |
# c2z A2F | GBA F2E | ADD FDF | Bde dBG F2A | A2G A2G A2G | A2A F2A | BAG AGA | BAG A2B |
# ADD GAB | c2A B2A | ~B3 BAG | ~B3 B2c2 | c2B A2A | B2A G2F | A4- | c2z | e2f | (3bagf dA FGFD |
# ~b2d2B2 | BAGE DEFA | BAGE | E2F2 A2 | B2B2 B2e2 | defe d2fd | dAdd =ccce |1 e2c2 ag | f2A2 de d2 :| c2 d2 d2 ||
# [K:F] GB cB =A2 | "Dm7"G2c B2A | "D"dBG2 {c}AG | FGEF | G2

# %%
# # Heatmap generation
# # Needed to make this 100x100 in order to be able to print it out as a nice lookin grid...
# heatmap = np.zeros((100,100))
# for neuron_idx in range(len(char_idx)-1):
#     for j, char in enumerate(char_idx):
#         #model.init_hidden()
#         out = model(Variable(seq_to_tensor(char))).data.view(-1)[neuron_idx]
#         heatmap[neuron_idx,j] = out

# %%
# # Adapted from https://stackoverflow.com/questions/25071968/heatmap-with-text-in-each-cell-with-matplotlibs-pyplot
# plt.rc('font', size=100)          # controls default text sizes
# plt.rc('axes', titlesize=100)     # fontsize of the axes title
# plt.rc('axes', labelsize=0)    # fontsize of the x and y labels
# plt.rc('xtick', labelsize=100)    # fontsize of the tick labels
# plt.rc('ytick', labelsize=100)    # fontsize of the tick labels
# plt.rc('legend', fontsize=100)    # legend fontsize
# plt.rc('figure', titlesize=100)  # fontsize of the figure title

# title = "Heatmap For Music RNN"
# xlabel= "Character"
# ylabel="Neuron ID"
# data =  np.reshape(heatmap[0,:], (10,-1))
# plt.figure(figsize=np.shape(heatmap))
# plt.title(title)
# plt.xlabel(xlabel)
# plt.ylabel(ylabel)
# c = plt.pcolor(data, edgecolors='k', linewidths=4, cmap='RdBu_r', vmin=-1.0, vmax=1.0)

# def show_values(pc, fmt="%.2f", **kw):
#     pc.update_scalarmappable()
#     ax = pc.axes
#     for p, color, value in zip(pc.get_paths(), pc.get_facecolors(), pc.get_array()):
#         x, y = p.vertices[:-2, :].mean(0)
#         if np.all(color[:3] > 0.5):
#             color = (0.0, 0.0, 0.0)
#         else:
#             color = (1.0, 1.0, 1.0)
#         idx = int(x-.5) + 10*int(y-.5)
#         if idx < len(char_idx):
#             ax.text(x, y, repr(char_list[idx])[1:-1], fontsize=180, ha="center", va="center", color=color, **kw)

# show_values(c)
# plt.colorbar(c)

# %%
# plt.show()

# %%
def get_h_for_heatmap(song_str):
    hidden = []  # container for hidden states
    model.init_hidden()
    
    prime = Variable(seq_to_tensor(song_str))
    for i in range(len(prime)):
        # pass each letter into LSTM
        _ = model(prime[i])
        # save the hidden variable
        hidden += [np.array(model.hidden[0].data.view(-1)).copy()]
    
    # return hidden variable for visualition.
    return np.vstack(hidden)
# Out:
# (1195, 100)

# %%
import colr
from colr import color
from matplotlib import cm
cmaps = cm.get_cmap('RdBu_r')

# cmaps(0)  # -> blue
# cmaps(1)  # -> red
# Out:
# (0.023913879277201077, 0.19653979238754324, 0.3919261822376009, 1.0)

# %%
song_vis = data[0]
hid = get_h_for_heatmap(song_vis)
print(hid.shape)
# Out:
# (783, 100)

# %%
for hiddden_unit in range(100):
    print('Hidden Unit: ', hiddden_unit)
    for i, c in enumerate(song_vis):
        i_color = (hid[i,hiddden_unit] + 1) / 2
        print(color(c, back=list(np.array(cmaps(i_color)[:3]) * 255)), end='')
    print()
# Out:
# Hidden Unit:  65
# <start>
# X:1
# T: La Montfarine
# Z:Transcrit et/ou corrig? par Michel BELLON - 2005-07-24
# Z:Pour toute observation mailto:galouvielle@free.fr
# M: 4/4
# L: 1/8
# Q:1/4=186
# FGF B=AG G=AG F2F FGF {F}F2E EFE|
# {E}E2D FGF B=AG G=AG {F}F2F FED C2G D2E|F3 {F}F/2 ED E3/2D/2|
# EC FE E2 DC|DC C2 GD2E|F3F/2F/2 DE FD|EC B,C D2 B,G|
# cB =A2 FG2E|F3F GF B=A|GG =AG F2 FF|GF F/2F3/2 EE FE|
# E/2E3/2 DF GF B=A|GG =AG F/2F3/2 FF|ED C2 GD2E|F3F/2F/2 ED E3/2D/2|
# EC FE E2 DC|DC C2 GD2E|F3F/2F/2 DE FD|EC B,C D2 B,G|
# cB =A2 FF G=A|B3
# G2_A G/2G3/2-|GF/2F/2 ED F2 EB,|CD EF GB AG|
# A3A GA F2|F/2F/2F EF D3/2B,/2 B,B,|CD EF GA GF|G3B/2B/2 AB G2|
# GG/2G/2 FG E2 EB/2B/2|AG BA GG AB|c3c/2c3/2d f2|ed eG c2 BB|
# AB dc BG AD|E3F GF BA|GG AG F2 FF|GF F/2F3/2 EE FE|
# E/2E3/2 DF GF BA|GG AG F/2F3/2 FF|ED C2 GD2E|F2- F/2
# <end>

# %%
header and end  6, 15, 35, 45, 76, 86, 94
date 13
not date 14

song body 19, 23, 57, 93
begining of song body 65

@ in the email 37

non letters 80
